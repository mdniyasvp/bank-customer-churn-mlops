# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("ggplot")
df = pd.read_csv("../data/raw/train.csv")

# %%
df.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# ...

# %%
df.shape
# Out:
# (165034, 14)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'CustomerId',
#  'Surname',
#  'CreditScore',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               165034 non-null  int64
#  1   CustomerId       165034 non-null  int64
#  2   Surname          165034 non-null  object
#  3   CreditScore      165034 non-null  int64
#  4   Geography        165034 non-null  object
#  5   Gender           165034 non-null  object
#  6   Age              165034 non-null  float64
#  7   Tenure           165034 non-null  int64
#  8   Balance          165034 non-null  float64
#  9   NumOfProducts    165034 non-null  int64
#  10  HasCrCard        165034 non-null  float64
#  11  IsActiveMember   165034 non-null  float64
#  12  EstimatedSalary  165034 non-null  float64
#  13  Exited           165034 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 17.6+ MB

# %%
df.describe().T
# Out:
#                     count          mean           std          min  \
# id               165034.0  8.251650e+04  47641.356500         0.00
# CustomerId       165034.0  1.569201e+07  71397.816791  15565701.00
# CreditScore      165034.0  6.564544e+02     80.103340       350.00
# Age              165034.0  3.812589e+01      8.867205        18.00
# Tenure           165034.0  5.020353e+00      2.806159         0.00
# Balance          165034.0  5.547809e+04  62817.663278         0.00
# NumOfProducts    165034.0  1.554455e+00      0.547154         1.00
# HasCrCard        165034.0  7.539537e-01      0.430707         0.00
# IsActiveMember   165034.0  4.977702e-01      0.499997         0.00
# EstimatedSalary  165034.0  1.125748e+05  50292.865585        11.58
# Exited           165034.0  2.115988e-01      0.408443         0.00
#
#                          25%         50%           75%          max
# id                  41258.25     82516.5  1.237748e+05    165033.00
# ...

# %%
df.isnull().sum()
# Out:
# id                 0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Exited"].value_counts()
# Out:
# Exited
# 0    130113
# 1     34921
# Name: count, dtype: int64

# %%
df["Exited"].value_counts(normalize = True) * 100
# Out:
# Exited
# 0    78.840118
# 1    21.159882
# Name: proportion, dtype: float64

# %%
df.dtypes
# Out:
# id                   int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                float64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard          float64
# IsActiveMember     float64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# | Column          | Type        | Meaning               | Use in Model |
# | --------------- | ----------- | --------------------- | ------------ |
# | id              | Identifier  | Row ID                | Drop         |
# | CustomerId      | Identifier  | Customer ID           | Drop         |
# | Surname         | Categorical | Customer surname      | Likely Drop  |
# | CreditScore     | Numerical   | Customer credit score | Keep         |
# | Geography       | Categorical | Customer location     | Keep         |
# | Gender          | Categorical | Male/Female           | Keep         |
# | Age             | Numerical   | Customer age          | Keep         |
# | Tenure          | Numerical   | Years with bank       | Keep         |
# | Balance         | Numerical   | Account balance       | Keep         |
# | NumOfProducts   | Numerical   | Number of products    | Keep         |
# | HasCrCard       | Binary      | Credit card holder    | Keep         |
# | IsActiveMember  | Binary      | Active member         | Keep         |
# | EstimatedSalary | Numerical   | Estimated salary      | Keep         |
# | Exited          | Target      | Customer churn        | Target       |
